# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk

# %%
x = "Сафар"
y = " Рагимов"
z = x + y
print(x)
print(y)
print(z)
# Out:
# Сафар
#  Рагимов
# Сафар Рагимов
