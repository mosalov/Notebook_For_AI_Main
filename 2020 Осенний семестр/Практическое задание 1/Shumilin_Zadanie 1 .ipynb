# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
x = "Михаил"
y = "Шумилин"
print(x)
print(y)
# Out:
# Михаил
# Шумилин

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
x = "Михаил "
y = "Шумилин"
z = x + y
print(z)
# Out:
# Михаил Шумилин

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
x = "Михаил "
y = "Шумилин"
z = x + y
len(z)
# Out:
# 14
