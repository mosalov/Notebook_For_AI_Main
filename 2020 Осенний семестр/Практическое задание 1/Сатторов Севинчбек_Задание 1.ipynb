# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
name='Sevinchbek'
surname='Sattorov'
full=name+" "+surname
print(full)
print(len(full))
# Out:
# Sevinchbek Sattorov
# 19
