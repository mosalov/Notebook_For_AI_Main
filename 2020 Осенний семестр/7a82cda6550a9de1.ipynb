# %%
import numpy as np
import sklearn as sk
from sklearn.metrics import mean_squared_error, classification_report, silhouette_samples
from sklearn.linear_model import LinearRegression

# %%
#Задание 1
y_true = [0,1,2,3]
y_pred = [6, 9, 6, 1]
print(mean_squared_error(y_true, y_pred))
# Out:
# 30.0

# %%
#Задание 2
y_true = [0,0,1,1,0,0,1,1,1]
y_pred = [0, 1, 1, 1, 1, 1, 1, 1, 0]
print(classification_report(y_true, y_pred, zero_division=False))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         4
#            1       0.57      0.80      0.67         5
#
#     accuracy                           0.56         9
#    macro avg       0.54      0.53      0.50         9
# weighted avg       0.54      0.56      0.52         9

# %%
#Задание 3
y = [0,0,1,1]
X = [(3, 3), (1, 4), (0, 2), (4, 4)]

sample_silhouette_values = silhouette_samples(X, y, metric='euclidean')
print('silhouette coefficients:', *sample_silhouette_values, sep='\n')

sample_silhouette_mean = sample_silhouette_values.mean()
print('silhouette mean: ', sample_silhouette_mean)
# Out:
# silhouette coefficients:
# 0.022802462075726084
# 0.14589803375031543
# -0.39644660940672616
# -0.5064759203666126
# silhouette mean:  -0.1835555084868243

# %%
#Задание 4
x = np.array([0, 1, 2]).reshape((-1, 1))
y = np.array([1, 3, 4])
model = LinearRegression().fit(x, y)
a = model.coef_[0]
b = model.intercept_
print(f'a = {a}\nb = {b}')
# Out:
# a = 1.4999999999999998
# b = 1.1666666666666667
