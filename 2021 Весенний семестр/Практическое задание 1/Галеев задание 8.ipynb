# %%
# Задание на повторение материала предыдущего семестра

# %%
# Зависимости
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, LogisticRegression
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.cluster import KMeans

from sklearn.metrics import mean_squared_error, f1_score, silhouette_score

# %%
# Генерируем уникальный seed
my_code = "Galeev"
seed_limit = 2 ** 32
my_seed = int.from_bytes(my_code.encode(), "little") % seed_limit

# %%
# Данные загружены отсюда: https://www.kaggle.com/dwdkills/russian-demography
# Читаем данные из файла
example_data = pd.read_csv("datasets/russian_demography.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9738be3d9c0a> in <module>
#       1 # Данные загружены отсюда: https://www.kaggle.com/dwdkills/russian-demography
#       2 # Читаем данные из файла
# ----> 3 example_data = pd.read_csv("datasets/russian_demography.csv")
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/russian_demography.csv'

# %%
# "year" - год (1990-2017)
# "region" - название региона
# "npg" - естественный прирост населения на 1000 человек
# "birth_rate" - количество рождений на 1000 человек
# "death_rate" - количество смертей на 1000 человек
# "gdw" - коэффициент демографической нагрузки на 100 человек (Отношение числа нетрудоспособных к числу трудоспособных).
# "urbanization" - процент городского населения

example_data.head()

# %%
# Так как список регионов меняется от года к году, в данных есть строки без значений. Удалим их
example_data.dropna(inplace=True)

# %%
# Определим размер валидационной и тестовой выборок
val_test_size = round(0.2*len(example_data))
print(val_test_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9c566b35fd1f> in <module>
#       1 # Определим размер валидационной и тестовой выборок
# ----> 2 val_test_size = round(0.2*len(example_data))
#       3 print(val_test_size)
#
# NameError: name 'example_data' is not defined

# %%
# Создадим обучающую, валидационную и тестовую выборки
random_state = my_seed
train_val, test = train_test_split(example_data, test_size=val_test_size, random_state=random_state)
train, val = train_test_split(train_val, test_size=val_test_size, random_state=random_state)
print(len(train), len(val), len(test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-03aa9e5fabfb> in <module>
#       1 # Создадим обучающую, валидационную и тестовую выборки
#       2 random_state = my_seed
# ----> 3 train_val, test = train_test_split(example_data, test_size=val_test_size, random_state=random_state)
#       4 train, val = train_test_split(train_val, test_size=val_test_size, random_state=random_state)
#       5 print(len(train), len(val), len(test))
#
# NameError: name 'example_data' is not defined

# %%
# Значения в числовых столбцах преобразуем к отрезку [0,1].
# Для настройки скалировщика используем только обучающую выборку.
columns_to_scale = ['year', 'npg', 'birth_rate', 'death_rate', 'gdw', 'urbanization']

ct = ColumnTransformer(transformers=[('numerical', MinMaxScaler(), columns_to_scale)], remainder='passthrough')
ct.fit(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e5d5c9080b5d> in <module>
#       4
#       5 ct = ColumnTransformer(transformers=[('numerical', MinMaxScaler(), columns_to_scale)], remainder='passthrough')
# ----> 6 ct.fit(train)
#
# NameError: name 'train' is not defined

# %%
# Преобразуем значения, тип данных приводим к DataFrame
sc_train = pd.DataFrame(ct.transform(train))
sc_test = pd.DataFrame(ct.transform(test))
sc_val = pd.DataFrame(ct.transform(val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-01b0f8e5d5a8> in <module>
#       1 # Преобразуем значения, тип данных приводим к DataFrame
# ----> 2 sc_train = pd.DataFrame(ct.transform(train))
#       3 sc_test = pd.DataFrame(ct.transform(test))
#       4 sc_val = pd.DataFrame(ct.transform(val))
#
# NameError: name 'train' is not defined

# %%
# Устанавливаем названия столбцов
column_names = columns_to_scale + ['region']
sc_train.columns = column_names
sc_test.columns = column_names
sc_val.columns = column_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d67c957b8d3a> in <module>
#       1 # Устанавливаем названия столбцов
#       2 column_names = columns_to_scale + ['region']
# ----> 3 sc_train.columns = column_names
#       4 sc_test.columns = column_names
#       5 sc_val.columns = column_names
#
# NameError: name 'sc_train' is not defined

# %%
sc_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1df54d12dcb5> in <module>
# ----> 1 sc_train
#
# NameError: name 'sc_train' is not defined

# %%
# Вспоминаем алгоритмы решения задачи регрессии: линейную регрессию и метод k ближайших соседей
r_models = []

# Линейная регрессия
# Для использования регуляризации, вместо LinearRegression используем Lasso, Ridge или ElasticNet
# Параметр alpha - коэффициент регуляризации для Lasso и Ridge, по умолчанию равен 1
# Для ElasticNet, если регуляризация иммет вид a*L1+b*L2, то
# параметр alpha = a + b, по умолчанию равен 1
# параметр l1_ratio = a / (a + b), по умолчанию равен 0.5
r_models.append(LinearRegression())
r_models.append(Lasso(alpha=1.0))
r_models.append(Ridge(alpha=1.0))
r_models.append(ElasticNet(alpha=1.0, l1_ratio=0.5))

# K ближайших соседей
# Параметр n_neighbors - количество соседей, по умолчания равен 5
r_models.append(KNeighborsRegressor(n_neighbors=5))
r_models.append(KNeighborsRegressor(n_neighbors=10))
r_models.append(KNeighborsRegressor(n_neighbors=15))

# %%
# Выделим предикторы и зависимую переменную
x_labels = column_names[0:-2]
y_labels = ['urbanization']

x_train = sc_train[x_labels]
x_test = sc_test[x_labels]
x_val = sc_val[x_labels]

y_train = sc_train[y_labels]
y_test = sc_test[y_labels]
y_val = sc_val[y_labels]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-13ab3147cdc9> in <module>
#       3 y_labels = ['urbanization']
#       4
# ----> 5 x_train = sc_train[x_labels]
#       6 x_test = sc_test[x_labels]
#       7 x_val = sc_val[x_labels]
#
# NameError: name 'sc_train' is not defined

# %%
# Обучаем модели
for model in r_models:
    model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e03bbe0d5747> in <module>
#       1 # Обучаем модели
#       2 for model in r_models:
# ----> 3     model.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
# Оценииваем качество работы моделей на валидационной выборке.
mses = []
for model in r_models:
    val_pred = model.predict(x_val)
    mse = mean_squared_error(y_val, val_pred)
    mses.append(mse)
    print(mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0e1a77d76b72> in <module>
#       2 mses = []
#       3 for model in r_models:
# ----> 4     val_pred = model.predict(x_val)
#       5     mse = mean_squared_error(y_val, val_pred)
#       6     mses.append(mse)
#
# NameError: name 'x_val' is not defined

# %%
# Выбираем лучшую модель
i_min = mses.index(min(mses))
best_r_model = r_models[i_min]
best_r_model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-92081a3ddcf2> in <module>
#       1 # Выбираем лучшую модель
# ----> 2 i_min = mses.index(min(mses))
#       3 best_r_model = r_models[i_min]
#       4 best_r_model
#
# ValueError: min() arg is an empty sequence

# %%
# Вычислим ошибку лучшей модели на тестовой выборке.
test_pred = best_r_model.predict(x_test)
mse = mean_squared_error(y_test, test_pred)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0a8538f2cba1> in <module>
#       1 # Вычислим ошибку лучшей модели на тестовой выборке.
# ----> 2 test_pred = best_r_model.predict(x_test)
#       3 mse = mean_squared_error(y_test, test_pred)
#       4 print(mse)
#
# NameError: name 'best_r_model' is not defined

# %%
# Вспоминаем алгоритмы решения задачи классификации:
# логистическую регрессию, наивный байесовский классификатор и (снова) метод k ближайших соседей
c_models = []

# Логистическая регрессия
# Параметр penalty - тип регуляризации: 'l1', 'l2', 'elasticnet', 'none'}, по умолчанию 'l2'
# Для некоторых типов регуляризации доступны не все алгоритмы (параметр solver)
# Для elasticnet регуляризации необходимо уазывать параметр l1_ratio (0 - l2, 1 - l1)
c_models.append(LogisticRegression(penalty='none', solver='saga'))
c_models.append(LogisticRegression(penalty='l1', solver='saga'))
c_models.append(LogisticRegression(penalty='l2', solver='saga'))
c_models.append(LogisticRegression(penalty='elasticnet', l1_ratio=0.5, solver='saga'))
c_models.append(LogisticRegression())

# Наивный байесовский классификатор
# Параметр alpha - параметр сглаживания, по умолчанию равен 1 (сглаживание Лапласа)
c_models.append(MultinomialNB(alpha=0.0))
c_models.append(MultinomialNB(alpha=0.5))
c_models.append(MultinomialNB(alpha=1.0))

# K ближайших соседей
# Параметр n_neighbors - количество соседей, по умолчания равен 5
c_models.append(KNeighborsClassifier(n_neighbors=5))
c_models.append(KNeighborsClassifier(n_neighbors=10))
c_models.append(KNeighborsClassifier(n_neighbors=15))

# %%
# Выделим предикторы и метки классов
x_labels = column_names[0:-1]
y_labels = ['region']

x_train = sc_train[x_labels]
x_test = sc_test[x_labels]
x_val = sc_val[x_labels]

y_train = np.ravel(sc_train[y_labels])
y_test = np.ravel(sc_test[y_labels])
y_val = np.ravel(sc_val[y_labels])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-36b0f13de1db> in <module>
#       3 y_labels = ['region']
#       4
# ----> 5 x_train = sc_train[x_labels]
#       6 x_test = sc_test[x_labels]
#       7 x_val = sc_val[x_labels]
#
# NameError: name 'sc_train' is not defined

# %%
# Обучаем модели
for model in c_models:
    model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-328f2d7eee09> in <module>
#       1 # Обучаем модели
#       2 for model in c_models:
# ----> 3     model.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
# Оценииваем качество работы моделей на валидационной выборке.
f1s = []
for model in c_models:
    val_pred = model.predict(x_val)
    f1 = f1_score(y_val, val_pred, average='weighted')
    f1s.append(f1)
    print(f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-fd5eadebc562> in <module>
#       2 f1s = []
#       3 for model in c_models:
# ----> 4     val_pred = model.predict(x_val)
#       5     f1 = f1_score(y_val, val_pred, average='weighted')
#       6     f1s.append(f1)
#
# NameError: name 'x_val' is not defined

# %%
# Выбираем лучшую модель
i_min = f1s.index(min(f1s))
best_c_model = c_models[i_min]
best_c_model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-3a8ec3db0dbf> in <module>
#       1 # Выбираем лучшую модель
# ----> 2 i_min = f1s.index(min(f1s))
#       3 best_c_model = c_models[i_min]
#       4 best_c_model
#
# ValueError: min() arg is an empty sequence

# %%
# Вычислим ошибку лучшей модели на тестовой выборке.
test_pred = best_c_model.predict(x_test)
f1 = f1_score(y_test, test_pred, average='weighted')
print(f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-14b288ebb1d1> in <module>
#       1 # Вычислим ошибку лучшей модели на тестовой выборке.
# ----> 2 test_pred = best_c_model.predict(x_test)
#       3 f1 = f1_score(y_test, test_pred, average='weighted')
#       4 print(f1)
#
# NameError: name 'best_c_model' is not defined

# %%
# Вспоминаем алгоритм решения задачи кластеризации - метод k-средних
# Параметр n_clusters - количество кластеров, по умолчанию равен 8
k_models = []
k_models.append(KMeans(n_clusters=5))
k_models.append(KMeans(n_clusters=8))
k_models.append(KMeans(n_clusters=20))
k_models.append(KMeans(n_clusters=50))

# %%
# Выделим используемые параметры
x_labels = column_names[0:-1]
x = pd.concat([sc_train[x_labels], sc_val[x_labels], sc_test[x_labels]])
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e1d3c8d4ad20> in <module>
#       1 # Выделим используемые параметры
#       2 x_labels = column_names[0:-1]
# ----> 3 x = pd.concat([sc_train[x_labels], sc_val[x_labels], sc_test[x_labels]])
#       4 x
#
# NameError: name 'sc_train' is not defined

# %%
# Произведем кластеризацию
for model in k_models:
    model.fit(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-69b76b371b04> in <module>
#       1 # Произведем кластеризацию
#       2 for model in k_models:
# ----> 3     model.fit(x)
#
# NameError: name 'x' is not defined

# %%
# Оценим качество результата
sils = []
for model in k_models:
    cluster_labels = model.predict(x)
    s = silhouette_score(x, cluster_labels)
    sils.append(s)
    print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-373e5fd8ff2d> in <module>
#       2 sils = []
#       3 for model in k_models:
# ----> 4     cluster_labels = model.predict(x)
#       5     s = silhouette_score(x, cluster_labels)
#       6     sils.append(s)
#
# NameError: name 'x' is not defined

# %%
# Выбираем лучшую модель
i_min = sils.index(min(sils))
best_k_model = k_models[i_min]
print(best_k_model)
print(sils[i_min])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-819f19caf66e> in <module>
#       1 # Выбираем лучшую модель
# ----> 2 i_min = sils.index(min(sils))
#       3 best_k_model = k_models[i_min]
#       4 print(best_k_model)
#       5 print(sils[i_min])
#
# ValueError: min() arg is an empty sequence

# %%
# Задание №1 - анализ моделей для задачи регрессии
# Общий список моделей
r_models = [
    LinearRegression(),
    Lasso(alpha=1.0),
    Lasso(alpha=0.5),
    Ridge(alpha=1.0),
    Ridge(alpha=0.5),
    ElasticNet(alpha=1.0, l1_ratio=0.5),
    ElasticNet(alpha=1.0, l1_ratio=0.25),
    ElasticNet(alpha=1.0, l1_ratio=0.75),
    ElasticNet(alpha=0.5, l1_ratio=0.5),
    ElasticNet(alpha=0.5, l1_ratio=0.25),
    ElasticNet(alpha=0.5, l1_ratio=0.75),
    KNeighborsRegressor(n_neighbors=5),
    KNeighborsRegressor(n_neighbors=10),
    KNeighborsRegressor(n_neighbors=15),
    KNeighborsRegressor(n_neighbors=20),
    KNeighborsRegressor(n_neighbors=25)
]

# %%
# Выбор моделей для задания
n = 4
random.seed(my_seed)
my_models1 = random.sample(r_models, n)
print(my_models1)
# Out:
# [LinearRegression(), KNeighborsRegressor(n_neighbors=10), KNeighborsRegressor(n_neighbors=15), Ridge()]

# %%
# Загрузим данные для задачи регрессии
data = pd.read_csv("datasets/weather.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-b257a33b474b> in <module>
#       1 # Загрузим данные для задачи регрессии
# ----> 2 data = pd.read_csv("datasets/weather.csv")
#       3 data
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/weather.csv'

# %%
data['water_level'] = data['water_level'].str.replace(',','.')
data['precipitation'] = data['precipitation'].str.replace(',','.')
data['temperature'] = data['temperature'].str.replace(',','.')
data['humidity'] = data['humidity'].str.replace(',','.')
data['visibility'] = data['visibility'].str.replace(',','.')
data['wind'] = data['wind'].str.replace(',','.')
data['weather'] = data['weather'].str.replace(',','.')
data['pressure'] = data['pressure'].str.replace(',','.')
data['fire'] = data['fire'].str.replace(',','.')                       
data['wl_changer'] = data['wl_change'].str.replace(',','.')                       
data['temp_change'] = data['temp_change'].str.replace(',','.')                      
data['pressure_change'] = data['pressure_change'].str.replace(',','.')

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
# Зависимая переменная для всех одна и та же. Предикторы выбираем случайнм образом.
columns = list(data.columns)
n_x = 5

y_label = ['water_level']
x_labels = random.sample(columns[1:], n_x)

print(x_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-e7cb75bf8e5c> in <module>
#       1 # Зависимая переменная для всех одна и та же. Предикторы выбираем случайнм образом.
# ----> 2 columns = list(data.columns)
#       3 n_x = 5
#       4
#       5 y_label = ['water_level']
#
# NameError: name 'data' is not defined

# %%
# Преобразуйте значения всех необходимых параметров к отрезку [0,1].
# Решите получившуюся задачу регрессии с помощью выбранных моделей и сравните их эффективность.

# %%
all_lb =  x_labels + y_label
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c05249ebdb0d> in <module>
# ----> 1 all_lb =  x_labels + y_label
#
# NameError: name 'y_label' is not defined

# %%
data=data[list(all_lb)]
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-6c46542ff2dc> in <module>
# ----> 1 data=data[list(all_lb)]
#       2 data
#
# NameError: name 'data' is not defined

# %%
# Определим размер валидационной и тестовой выборок
val_test_size = round(0.2*len(data))
print(val_test_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-321db5540f59> in <module>
#       1 # Определим размер валидационной и тестовой выборок
# ----> 2 val_test_size = round(0.2*len(data))
#       3 print(val_test_size)
#
# NameError: name 'data' is not defined

# %%
# Создадим обучающую, валидационную и тестовую выборки
random_state = my_seed
train_val, test = train_test_split(data, test_size=val_test_size, random_state=random_state)
train, val = train_test_split(train_val, test_size=val_test_size, random_state=random_state)
print(len(train), len(val), len(test))

# %%
# Значения в числовых столбцах преобразуем к отрезку [0,1].
# Для настройки скалировщика используем только обучающую выборку.
columns_to_scale = all_lb

ct = ColumnTransformer(transformers=[('numerical', MinMaxScaler(), columns_to_scale)], remainder='passthrough')
ct.fit(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-60e610992b31> in <module>
#       1 # Значения в числовых столбцах преобразуем к отрезку [0,1].
#       2 # Для настройки скалировщика используем только обучающую выборку.
# ----> 3 columns_to_scale = all_lb
#       4
#       5 ct = ColumnTransformer(transformers=[('numerical', MinMaxScaler(), columns_to_scale)], remainder='passthrough')
#
# NameError: name 'all_lb' is not defined

# %%
# Преобразуем значения, тип данных приводим к DataFrame
sc_train = pd.DataFrame(ct.transform(train))
sc_test = pd.DataFrame(ct.transform(test))
sc_val = pd.DataFrame(ct.transform(val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-01b0f8e5d5a8> in <module>
#       1 # Преобразуем значения, тип данных приводим к DataFrame
# ----> 2 sc_train = pd.DataFrame(ct.transform(train))
#       3 sc_test = pd.DataFrame(ct.transform(test))
#       4 sc_val = pd.DataFrame(ct.transform(val))
#
# NameError: name 'train' is not defined

# %%
# Устанавливаем названия столбцов
column_names = all_lb
sc_train.columns = column_names
sc_test.columns = column_names
sc_val.columns = column_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-094272111b0a> in <module>
#       1 # Устанавливаем названия столбцов
# ----> 2 column_names = all_lb
#       3 sc_train.columns = column_names
#       4 sc_test.columns = column_names
#       5 sc_val.columns = column_names
#
# NameError: name 'all_lb' is not defined

# %%
sc_train

# %%
x_train = sc_train[x_labels]
x_test = sc_test[x_labels]
x_val = sc_val[x_labels]

y_train = sc_train[y_label]
y_test = sc_test[y_label]
y_val = sc_val[y_label]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-cef10a4eb685> in <module>
# ----> 1 x_train = sc_train[x_labels]
#       2 x_test = sc_test[x_labels]
#       3 x_val = sc_val[x_labels]
#       4
#       5 y_train = sc_train[y_label]
#
# NameError: name 'sc_train' is not defined

# %%
# Обучаем модели
for model in my_models1:
    model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d5fec87a041f> in <module>
#       1 # Обучаем модели
#       2 for model in my_models1:
# ----> 3     model.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
# Оценииваем качество работы моделей на валидационной выборке.
mses = []
for model in my_models1:
    val_pred = model.predict(x_val)
    mse = mean_squared_error(y_val, val_pred)
    mses.append(mse)
    print(mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-cae84557eb25> in <module>
#       2 mses = []
#       3 for model in my_models1:
# ----> 4     val_pred = model.predict(x_val)
#       5     mse = mean_squared_error(y_val, val_pred)
#       6     mses.append(mse)
#
# NameError: name 'x_val' is not defined

# %%
# Выбираем лучшую модель # Укажите, какая модель решает задачу лучше других.
i_min = mses.index(min(mses))
best_my_model = my_models1[i_min]
print('Модель ', best_my_model, 'решает задачу лучше других.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-06b9d9e934ad> in <module>
#       1 # Выбираем лучшую модель # Укажите, какая модель решает задачу лучше других.
# ----> 2 i_min = mses.index(min(mses))
#       3 best_my_model = my_models1[i_min]
#       4 print('Модель ', best_my_model, 'решает задачу лучше других.')
#
# ValueError: min() arg is an empty sequence

# %%
# Вычислим ошибку лучшей модели на тестовой выборке.
test_pred = best_r_model.predict(x_test)
mse = mean_squared_error(y_test, test_pred)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-0a8538f2cba1> in <module>
#       1 # Вычислим ошибку лучшей модели на тестовой выборке.
# ----> 2 test_pred = best_r_model.predict(x_test)
#       3 mse = mean_squared_error(y_test, test_pred)
#       4 print(mse)
#
# NameError: name 'best_r_model' is not defined

# %%
# Задание №2 - анализ моделей для задачи классификации
# Общий список моделей
c_models = [
    LogisticRegression(penalty='none', solver='saga'),
    LogisticRegression(penalty='l1', solver='saga'),
    LogisticRegression(penalty='l2', solver='saga'),
    LogisticRegression(penalty='elasticnet', l1_ratio=0.25, solver='saga'),
    LogisticRegression(penalty='elasticnet', l1_ratio=0.5, solver='saga'),
    LogisticRegression(penalty='elasticnet', l1_ratio=0.75, solver='saga'),
    LogisticRegression(),
    MultinomialNB(alpha=0.0),
    MultinomialNB(alpha=0.25),
    MultinomialNB(alpha=0.5),
    MultinomialNB(alpha=0.75),
    MultinomialNB(alpha=1.0),
    KNeighborsClassifier(n_neighbors=5),
    KNeighborsClassifier(n_neighbors=10),
    KNeighborsClassifier(n_neighbors=15),
    KNeighborsClassifier(n_neighbors=20),
    KNeighborsClassifier(n_neighbors=25)
]

# %%
# Выбор моделей для задания
n = 5
my_models2 = random.sample(c_models, n)
print(my_models2)
# Out:
# [LogisticRegression(), KNeighborsClassifier(), LogisticRegression(l1_ratio=0.25, penalty='elasticnet', solver='saga'), KNeighborsClassifier(n_neighbors=20), KNeighborsClassifier(n_neighbors=15)]

# %%
# Загрузим данные для задачи классификации
data = pd.read_csv("datasets/zoo2.csv")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-0222ec6aec1c> in <module>
#       1 # Загрузим данные для задачи классификации
# ----> 2 data = pd.read_csv("datasets/zoo2.csv")
#       3 data
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/zoo2.csv'

# %%
#data.drop(['animal_name'], axis='columns', inplace=True)

# %%
#data.head()

# %%
data['animal_name'] = pd.get_dummies(data['animal_name'])
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-06545d3676e5> in <module>
# ----> 1 data['animal_name'] = pd.get_dummies(data['animal_name'])
#       2 data.head()
#
# NameError: name 'data' is not defined

# %%
# Метка класса для всех одна и та же. Параметры выбираем случайнм образом.
columns = list(data.columns)
n_x = 8

y_label = ['class_type']
x_labels = random.sample(columns[:-1], n_x)
all_lb1 =  x_labels + y_label
print(x_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-7535c984077d> in <module>
#       1 # Метка класса для всех одна и та же. Параметры выбираем случайнм образом.
# ----> 2 columns = list(data.columns)
#       3 n_x = 8
#       4
#       5 y_label = ['class_type']
#
# NameError: name 'data' is not defined

# %%
# Преобразуйте значения всех необходимых параметров к отрезку [0,1].
# Решите получившуюся задачу классификации с помощью выбранных моделей и сравните их эффективность.
# Укажите, какая модель решает задачу лучше других.

# %%
data=data[list(all_lb1)]
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-1bcf16ac0b54> in <module>
# ----> 1 data=data[list(all_lb1)]
#       2 data.head()
#
# NameError: name 'data' is not defined

# %%
# Определим размер валидационной и тестовой выборок
val_test_size = round(0.2*len(data))
print(val_test_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-321db5540f59> in <module>
#       1 # Определим размер валидационной и тестовой выборок
# ----> 2 val_test_size = round(0.2*len(data))
#       3 print(val_test_size)
#
# NameError: name 'data' is not defined

# %%
# Создадим обучающую, валидационную и тестовую выборки
random_state = my_seed
train_val, test = train_test_split(data, test_size=val_test_size, random_state=random_state)
train, val = train_test_split(train_val, test_size=val_test_size, random_state=random_state)
print(len(train), len(val), len(test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-6758d01b1723> in <module>
#       1 # Создадим обучающую, валидационную и тестовую выборки
#       2 random_state = my_seed
# ----> 3 train_val, test = train_test_split(data, test_size=val_test_size, random_state=random_state)
#       4 train, val = train_test_split(train_val, test_size=val_test_size, random_state=random_state)
#       5 print(len(train), len(val), len(test))
#
# NameError: name 'data' is not defined

# %%
# Значения в числовых столбцах преобразуем к отрезку [0,1].
# Для настройки скалировщика используем только обучающую выборку.
columns_to_scale = x_labels#all_lb1

ct = ColumnTransformer(transformers=[('numerical', MinMaxScaler(), columns_to_scale)], remainder='passthrough')
ct.fit(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-3e05d37dc4c0> in <module>
#       4
#       5 ct = ColumnTransformer(transformers=[('numerical', MinMaxScaler(), columns_to_scale)], remainder='passthrough')
# ----> 6 ct.fit(train)
#
# NameError: name 'train' is not defined

# %%
# Преобразуем значения, тип данных приводим к DataFrame
sc_train = pd.DataFrame(ct.transform(train))
sc_test = pd.DataFrame(ct.transform(test))
sc_val = pd.DataFrame(ct.transform(val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-01b0f8e5d5a8> in <module>
#       1 # Преобразуем значения, тип данных приводим к DataFrame
# ----> 2 sc_train = pd.DataFrame(ct.transform(train))
#       3 sc_test = pd.DataFrame(ct.transform(test))
#       4 sc_val = pd.DataFrame(ct.transform(val))
#
# NameError: name 'train' is not defined

# %%
# Устанавливаем названия столбцов
column_names = all_lb1
sc_train.columns = column_names
sc_test.columns = column_names
sc_val.columns = column_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-f1f8f7335591> in <module>
#       1 # Устанавливаем названия столбцов
# ----> 2 column_names = all_lb1
#       3 sc_train.columns = column_names
#       4 sc_test.columns = column_names
#       5 sc_val.columns = column_names
#
# NameError: name 'all_lb1' is not defined

# %%
sc_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-1df54d12dcb5> in <module>
# ----> 1 sc_train
#
# NameError: name 'sc_train' is not defined

# %%
x_train = sc_train[x_labels]
x_test = sc_test[x_labels]
x_val = sc_val[x_labels]

y_train = np.ravel(sc_train[y_label])
y_test = np.ravel(sc_test[y_label])
y_val = np.ravel(sc_val[y_label])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-cc1fe315757e> in <module>
# ----> 1 x_train = sc_train[x_labels]
#       2 x_test = sc_test[x_labels]
#       3 x_val = sc_val[x_labels]
#       4
#       5 y_train = np.ravel(sc_train[y_label])
#
# NameError: name 'sc_train' is not defined

# %%
# Обучаем модели
for model2 in my_models2:
    model2.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-3192f8cfee09> in <module>
#       1 # Обучаем модели
#       2 for model2 in my_models2:
# ----> 3     model2.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
# Оценииваем качество работы моделей на валидационной выборке.
f1s = []
for model in my_models2:
    val_pred = model.predict(x_val)
    f1 = f1_score(y_val, val_pred, average='weighted')
    f1s.append(f1)
    print(f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-de2a6650e6b1> in <module>
#       2 f1s = []
#       3 for model in my_models2:
# ----> 4     val_pred = model.predict(x_val)
#       5     f1 = f1_score(y_val, val_pred, average='weighted')
#       6     f1s.append(f1)
#
# NameError: name 'x_val' is not defined

# %%
# Выбираем лучшую модель # Укажите, какая модель решает задачу лучше других.
i_min = f1s.index(min(f1s))
best_my_models2 = my_models2[i_min]
print('Модель ', best_my_models2, 'решает задачу лучше других.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-2caa703e107f> in <module>
#       1 # Выбираем лучшую модель # Укажите, какая модель решает задачу лучше других.
# ----> 2 i_min = f1s.index(min(f1s))
#       3 best_my_models2 = my_models2[i_min]
#       4 print('Модель ', best_my_models2, 'решает задачу лучше других.')
#
# ValueError: min() arg is an empty sequence

# %%
# Вычислим ошибку лучшей модели на тестовой выборке.
test_pred = best_my_models2.predict(x_test)
f1 = f1_score(y_test, test_pred, average='weighted')
print(f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-6d926d93258b> in <module>
#       1 # Вычислим ошибку лучшей модели на тестовой выборке.
# ----> 2 test_pred = best_my_models2.predict(x_test)
#       3 f1 = f1_score(y_test, test_pred, average='weighted')
#       4 print(f1)
#
# NameError: name 'best_my_models2' is not defined
