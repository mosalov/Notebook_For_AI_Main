# %%
import numpy as np
import pandas
import matplotlib.pyplot

x = []
df1 = pandas.DataFrame()

for i in np.arange(-10, 10.1, 0.1):
    x.append(round(i, 1))
    #print(i)

df1['X'] = x
df1['Y'] = 1 / df1['X']

matplotlib.pyplot.plot(df1['X'], df1['Y'])
