# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
df = pd.DataFrame()
df.insert(0, 'Число', range(1, 11))
df['Квадрат'] = df['Число']**2
df2 = df[df['Число']%2 == 0]
df2 = df2.drop(['Число'], axis = 1)
print(df2)
# Out:
#    Квадрат
# 1        4
# 3       16
# 5       36
# 7       64
# 9      100
