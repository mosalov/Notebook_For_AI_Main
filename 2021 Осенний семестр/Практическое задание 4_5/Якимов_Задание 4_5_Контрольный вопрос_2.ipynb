# %%
import numpy
import pandas
import matplotlib.pyplot
x = list(range(-10,11))
y = list()
for i in x:
    if i != 0:
        y.append(1/i) 
    else:
        y.append(None)           
matplotlib.pyplot.plot(x, y)
