# %%
import numpy
import pandas
import matplotlib.pyplot

# %%
x1 = numpy.arange(-10,0)
x2 = numpy.arange(1,11)
matplotlib.pyplot.plot(x1, 1/x1, color="blue")+ matplotlib.pyplot.plot(x2, 1/x2, color="blue")
