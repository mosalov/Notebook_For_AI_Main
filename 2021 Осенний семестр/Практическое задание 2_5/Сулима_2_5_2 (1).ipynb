# %%
x=10
y=25


sum=x+y
com=x*y
dif=x-y
priv=x/y
print('Summa Ravna: ' +str(sum))
print('Raznost: ' +str(dif))
print('Proizvedenie: ' +str(com))
print('Chastnot Ravnp: ' +str(priv))
formula=((x**2+y)*(y-1))/(x-y+y**2)
print(formula)
# Out:
# Summa Ravna: 35
# Raznost: -15
# Proizvedenie: 250
# Chastnot Ravnp: 0.4
# 4.918032786885246
