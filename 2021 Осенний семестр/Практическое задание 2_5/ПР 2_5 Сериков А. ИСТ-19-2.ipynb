# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk

# %%
x=10
y=25
f=(((x**2)+y)*(y-1))/(x-y+(y**2))
f
# Out:
# 4.918032786885246

# %%
x=1
y=1
if x>y:
  print("x больше y")
elif x<y:
  print("x меньше y")
elif x==y:
  print("x равно y")
# Out:
# x равно y

# %%
SpIsOk=lst=[2,4,6,8,10]
for i in SpIsOk:
  if i>5:
    print(i)
  elif i<5:
    print(i*-1)
# Out:
# -2
# -4
# 6
# 8
# 10

# %%
n = int(input())
factorial = 1
while n > 1:
    factorial *= n
    n -= 1
print(factorial)
# Out:
# 10
# 3628800
