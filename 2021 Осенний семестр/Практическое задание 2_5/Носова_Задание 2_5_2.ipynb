# %%
x=10
y=25

sum = x+y
dif = x-y
com = x*y
pri = x/y

print('сумма равна ' + str(sum))
print('разность равна ' + str(dif))
print('произведение равно ' + str(com))
print('частное равно ' + str(pri))
# Out:
# сумма равна 35
# разность равна -15
# произведение равно 250
# частное равно 0.4

# %%
z = ((x**2+y)*(y-1))/(x-y+y**2)

print('значение выражения равно ' + str(z))
# Out:
# значение выражения равно 4.918032786885246
