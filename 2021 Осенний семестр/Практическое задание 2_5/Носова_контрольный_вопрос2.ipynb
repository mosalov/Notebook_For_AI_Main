# %%
x = int (input ('введите любое число: '))
a = 0
for i in range(2, x // 2+1):
    if (x % i == 0):
        a = a+1
if (a <= 0):
    print("Число простое")
else:
    print("Число не  простое")
# Out:
# введите любое число:  55
# Число не  простое
