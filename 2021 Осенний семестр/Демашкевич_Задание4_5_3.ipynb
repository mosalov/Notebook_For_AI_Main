# %%
import numpy
import pandas
import matplotlib.pyplot

# %%
a = pandas.read_csv("winequality-white.csv",";")

# %%
b = a
for i in range(0,(a.shape[0])):
    if ((a["residual sugar"][i])>=1):
        b = b.drop(index=[i])
print (b)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 54              6.8              0.20         0.59             0.9      0.147
# 172             7.6              0.48         0.37             0.8      0.037
# 209             6.1              0.40         0.31             0.9      0.048
# 223             6.5              0.19         0.30             0.8      0.043
# 259             5.8              0.36         0.38             0.9      0.037
# ...             ...               ...          ...             ...        ...
# 4804            6.0              0.35         0.46             0.9      0.033
# 4877            5.9              0.54         0.00             0.8      0.032
# 4878            6.2              0.53         0.02             0.9      0.035
# 4891            5.7              0.21         0.32             0.9      0.038
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
c = b.columns.values.tolist()
i = 0
while i < 7:
    b.pop(c[i])
    i+=1
i = 9
while i < 12:
    b.pop(c[i])
    i+=1
print(b)
# Out:
#       density    pH
# 54    0.99300  3.05
# 172   0.99020  3.03
# 209   0.99300  3.22
# 223   0.99360  3.42
# 259   0.99040  3.28
# ...       ...   ...
# 4804  0.98934  3.24
# 4877  0.99286  3.25
# 4878  0.99234  3.24
# 4891  0.99074  3.24
# 4897  0.98941  3.26
#
# [77 rows x 2 columns]

# %%
b = b [1::2]
print(b)
# Out:
#       density    pH
# 172   0.99020  3.03
# 223   0.99360  3.42
# 301   0.99200  3.13
# 595   0.99260  3.45
# 913   0.99240  3.36
# 957   0.99260  3.39
# 1166  0.99270  3.23
# 1340  0.99220  3.27
# 1366  0.99140  3.25
# 1389  0.99260  3.06
# 1425  0.99100  3.25
# 1486  0.99320  3.30
# 1817  0.99320  3.19
# 2045  0.99260  3.08
# 2468  0.99155  3.25
# 2587  0.99190  3.22
# 2609  0.98931  3.20
# 2647  0.99198  3.24
# 2815  0.99066  3.23
# 2859  0.99165  3.24
# 2898  0.99104  2.99
# 2934  0.99215  3.30
# 2956  0.99026  2.80
# 2970  0.99038  2.93
# 2996  0.98942  3.11
# 3119  0.98970  3.09
# 3143  0.99026  3.50
# 3212  0.99033  3.25
# 3409  0.99160  3.37
# 3526  0.98984  3.01
# 3557  0.99062  2.92
# 3626  0.99048  3.21
# 3924  0.99249  2.95
# 4487  0.99175  3.47
# 4681  0.98845  3.29
# 4779  0.99032  3.10
# 4877  0.99286  3.25
# 4891  0.99074  3.24
