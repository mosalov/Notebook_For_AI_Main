# %%
import numpy
import pandas
import matplotlib.pyplot

# %%
d=('white','blue','red','yellow','green','orange')
a1 =['      ','      ','       ']
a2 =[a1]*3
a3 = [a2]*6
b = numpy.array(a3)
for n in range(0,6):
    for i in range(0,3):
        for j in range(0,3):
            b[n][i][j]= d[n]
print (b)
# Out:
# [[['white' 'white' 'white']
#   ['white' 'white' 'white']
#   ['white' 'white' 'white']]
#
#  [['blue' 'blue' 'blue']
#   ['blue' 'blue' 'blue']
#   ['blue' 'blue' 'blue']]
#
#  [['red' 'red' 'red']
#   ['red' 'red' 'red']
#   ['red' 'red' 'red']]
#
#  [['yellow' 'yellow' 'yellow']
#   ['yellow' 'yellow' 'yellow']
#   ['yellow' 'yellow' 'yellow']]
#
#  [['green' 'green' 'green']
#   ['green' 'green' 'green']
#   ['green' 'green' 'green']]
#
#  [['orange' 'orange' 'orange']
#   ['orange' 'orange' 'orange']
#   ['orange' 'orange' 'orange']]]
