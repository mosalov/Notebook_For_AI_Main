# %%
d={}
d[1]=10
d['abc']='def'
d[0]=[0, 1, 2]
d[(0, 1)]='а'

print(d)

d[1]=d[1]+5
d['abc']=d['abc']*2
d[0].append(3)
d[0]=d[0][1:]
d.pop((0, 1))

print(d)
# Out:
# {1: 10, 'abc': 'def', 0: [0, 1, 2], (0, 1): 'а'}
# {1: 15, 'abc': 'defdef', 0: [1, 2, 3]}
