# %%
import numpy
import pandas
import matplotlib.pyplot

# %%
a = pandas.read_csv("4_5_3.csv")

# %%
print(a)
# Out:
#     density    pH
# 0   0.99020  3.03
# 1   0.99360  3.42
# 2   0.99200  3.13
# 3   0.99260  3.45
# 4   0.99240  3.36
# 5   0.99260  3.39
# 6   0.99270  3.23
# 7   0.99220  3.27
# 8   0.99140  3.25
# 9   0.99260  3.06
# 10  0.99100  3.25
# 11  0.99320  3.30
# 12  0.99320  3.19
# 13  0.99260  3.08
# 14  0.99155  3.25
# 15  0.99190  3.22
# 16  0.98931  3.20
# 17  0.99198  3.24
# 18  0.99066  3.23
# 19  0.99165  3.24
# 20  0.99104  2.99
# 21  0.99215  3.30
# 22  0.99026  2.80
# 23  0.99038  2.93
# 24  0.98942  3.11
# 25  0.98970  3.09
# 26  0.99026  3.50
# 27  0.99033  3.25
# 28  0.99160  3.37
# 29  0.98984  3.01
# 30  0.99062  2.92
# 31  0.99048  3.21
# 32  0.99249  2.95
# 33  0.99175  3.47
# 34  0.98845  3.29
# 35  0.99032  3.10
# 36  0.99286  3.25
# 37  0.99074  3.24

# %%
x = a["pH"]
matplotlib.pyplot.hist(x)
# Out:
# (array([ 1.,  2.,  2.,  3.,  5.,  3., 12.,  3.,  4.,  3.]),
#  array([2.8 , 2.87, 2.94, 3.01, 3.08, 3.15, 3.22, 3.29, 3.36, 3.43, 3.5 ]),
#  <BarContainer object of 10 artists>)

# %%
x = a["density"]
matplotlib.pyplot.plot(x)
