# %%
name=list('vanya')
name
# Out:
# ['v', 'a', 'n', 'y', 'a']

# %%
name2=name.copy()
name2
# Out:
# ['v', 'a', 'n', 'y', 'a']

# %%
name2.sort()
name2
# Out:
# ['a', 'a', 'n', 'v', 'y']

# %%
name3=name+name2
name3
# Out:
# ['v', 'a', 'n', 'y', 'a', 'a', 'a', 'n', 'v', 'y']

# %%
del name3[0:3]
name3
# Out:
# ['y', 'a', 'a', 'a', 'n', 'v', 'y']

# %%
name
# Out:
# ['v', 'a', 'n', 'y', 'a']

# %%
name2
# Out:
# ['a', 'a', 'n', 'v', 'y']
