# %%
x = list('Alexandr')
y = sorted(x)

z = x + y

for i in range(0,3) :
    z.pop(0)

print(x)
print(y)
print(z)
# Out:
# ['A', 'l', 'e', 'x', 'a', 'n', 'd', 'r']
# ['A', 'a', 'd', 'e', 'l', 'n', 'r', 'x']
# ['x', 'a', 'n', 'd', 'r', 'A', 'a', 'd', 'e', 'l', 'n', 'r', 'x']
