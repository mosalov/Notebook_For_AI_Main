# %%
zxc = {}
zxc = dict({1:10, 'abc':'def', 0:[0,1,2], (0,1):'a'})
zxc[1] += 5
zxc['abc'] += zxc.get('abc')
zxc[0].append(3)
zxc[0].pop(0)
del zxc[(0,1)]
print(zxc)
# Out:
# {1: 15, 'abc': 'defdef', 0: [1, 2, 3]}
