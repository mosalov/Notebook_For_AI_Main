# %%
x = {}

x[1] = 10
x['abc'] = 'def'
x[0] = [0, 1, 2]
x[0, 1] = 'a'

print(x)

x[1] += 5
x['abc'] += x['abc']
x[0].append(5)
x[0].pop(0)

#далее ищу ключ по заданному значению, после чего удаляю
for key in list(x.keys()):
    if x[key] == 'a':
        del x[key]

print(x)
# Out:
# {1: 10, 'abc': 'def', 0: [0, 1, 2], (0, 1): 'a'}
# {1: 15, 'abc': 'defdef', 0: [1, 2, 5]}
