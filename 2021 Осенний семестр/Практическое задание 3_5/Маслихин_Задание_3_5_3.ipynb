# %%
x=list('СТЕПАН')
y=x.copy()
y.sort() 
z=x.copy()+y.copy()
z=z[3:]
print(x)
print(y)
print(z)
# Out:
# ['С', 'Т', 'Е', 'П', 'А', 'Н']
# ['А', 'Е', 'Н', 'П', 'С', 'Т']
# ['П', 'А', 'Н', 'А', 'Е', 'Н', 'П', 'С', 'Т']
