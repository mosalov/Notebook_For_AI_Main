# %%
import copy
list=['y','a','r','o','s','l','a','v']
list2=copy.copy(list)
print('Изначальный список''='+str(list))
print('Второй список''='+str(sorted(list2)))
list3=list+list2
list3.remove('y')
list3.remove('a')
list3.remove('r')
print('Третий список''='+str(list3))
# Out:
# Изначальный список=['y', 'a', 'r', 'o', 's', 'l', 'a', 'v']
# Второй список=['a', 'a', 'l', 'o', 'r', 's', 'v', 'y']
# Третий список=['o', 's', 'l', 'a', 'v', 'y', 'a', 'r', 'o', 's', 'l', 'a', 'v']
