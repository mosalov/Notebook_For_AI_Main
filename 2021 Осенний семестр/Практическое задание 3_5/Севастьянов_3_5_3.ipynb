# %%
n = list('никита')
m = n.copy()
m = sorted(m)
l = n + m
l = l[3:]
print(n,m,l)
# Out:
# ['н', 'и', 'к', 'и', 'т', 'а'] ['а', 'и', 'и', 'к', 'н', 'т'] ['и', 'т', 'а', 'а', 'и', 'и', 'к', 'н', 'т']
