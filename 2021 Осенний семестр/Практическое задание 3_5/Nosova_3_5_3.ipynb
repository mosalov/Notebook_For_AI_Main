# %%
n = list('olesya')
m = n.copy()
m = sorted(m)
l = n + m
l = l[3:]
print(n,m,l)
# Out:
# ['o', 'l', 'e', 's', 'y', 'a'] ['a', 'e', 'l', 'o', 's', 'y'] ['s', 'y', 'a', 'a', 'e', 'l', 'o', 's', 'y']
