# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk

name = "Stepa"
last_name = "Makarov"

full = name + " " + last_name
print(full)
# Out:
# Stepa Makarov
