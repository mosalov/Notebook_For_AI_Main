# %%
# Зависимости
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer

from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.metrics import mean_squared_error, f1_score, silhouette_score

from sklearn import preprocessing

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
# Инициализируем все известные генераторы случаынйх чисел / Setting all known random seeds
my_code = "Fakhrutdinov"
seed_limit = 2 ** 32
my_seed = int.from_bytes(my_code.encode(), "little") % seed_limit

os.environ['PYTHONHASHSEED']=str(my_seed)

random.seed(my_seed)

np.random.seed(my_seed)

tf.compat.v1.set_random_seed(my_seed)

session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %%
# Читаем данные из файла
train_data = pd.read_csv("datasets/iris_train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_80/915179856.py in <module>
#       1 # Читаем данные из файла
# ----> 2 train_data = pd.read_csv("datasets/iris_train.csv")
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/iris_train.csv'

# %%
train_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/1070689878.py in <module>
# ----> 1 train_data.head()
#
# NameError: name 'train_data' is not defined

# %%
classes = train_data['species']
plt.hist(classes)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/24258695.py in <module>
# ----> 1 classes = train_data['species']
#       2 plt.hist(classes)
#       3 plt.show()
#
# NameError: name 'train_data' is not defined

# %%
# Определим размер валидационной выборки
val_size = round(0.2*len(train_data))
print(val_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/4106514532.py in <module>
#       1 # Определим размер валидационной выборки
# ----> 2 val_size = round(0.2*len(train_data))
#       3 print(val_size)
#
# NameError: name 'train_data' is not defined

# %%
# Создадим обучающую и валидационную выборки
random_state = my_seed
train, val = train_test_split(train_data, test_size=val_size, random_state=random_state)
print(len(train), len(val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/4077260988.py in <module>
#       1 # Создадим обучающую и валидационную выборки
#       2 random_state = my_seed
# ----> 3 train, val = train_test_split(train_data, test_size=val_size, random_state=random_state)
#       4 print(len(train), len(val))
#
# NameError: name 'train_data' is not defined

# %%
# Значения в числовых столбцах преобразуем к отрезку [0,1].
# Для настройки скалировщика используем только обучающую выборку.
num_columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
ord_columns = ['species']

ct = ColumnTransformer(transformers=[('numerical', MinMaxScaler(), num_columns)], remainder='passthrough')

ct.fit(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2243419831.py in <module>
#       6 ct = ColumnTransformer(transformers=[('numerical', MinMaxScaler(), num_columns)], remainder='passthrough')
#       7
# ----> 8 ct.fit(train)
#
# NameError: name 'train' is not defined

# %%
# Преобразуем значения, тип данных приводим к DataFrame
sc_train = pd.DataFrame(ct.transform(train))
sc_val = pd.DataFrame(ct.transform(val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/368249373.py in <module>
#       1 # Преобразуем значения, тип данных приводим к DataFrame
# ----> 2 sc_train = pd.DataFrame(ct.transform(train))
#       3 sc_val = pd.DataFrame(ct.transform(val))
#
# NameError: name 'train' is not defined

# %%
# Устанавливаем названия столбцов
column_names = num_columns + ord_columns
sc_train.columns = column_names
sc_val.columns = column_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/3508156740.py in <module>
#       1 # Устанавливаем названия столбцов
#       2 column_names = num_columns + ord_columns
# ----> 3 sc_train.columns = column_names
#       4 sc_val.columns = column_names
#
# NameError: name 'sc_train' is not defined

# %%
sc_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2751886009.py in <module>
# ----> 1 sc_train
#
# NameError: name 'sc_train' is not defined

# %%
# Отберем необходимые параметры
x_train = sc_train[num_columns]
x_val = sc_val[num_columns]

y_train = (sc_train[ord_columns].values).flatten()
y_val = (sc_val[ord_columns].values).flatten()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/3489225857.py in <module>
#       1 # Отберем необходимые параметры
# ----> 2 x_train = sc_train[num_columns]
#       3 x_val = sc_val[num_columns]
#       4
#       5 y_train = (sc_train[ord_columns].values).flatten()
#
# NameError: name 'sc_train' is not defined

# %%
classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()

]

# %%
for model in classifiers:
    print(model)
    model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/3044004487.py in <module>
#       1 for model in classifiers:
#       2     print(model)
# ----> 3     model.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
f1s = []
for model in classifiers:
    val_pred = model.predict(x_val)
    f1 = f1_score(y_val, val_pred, average='weighted')
    f1s.append(f1)
    print(model, '\t', f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2379553514.py in <module>
#       1 f1s = []
#       2 for model in classifiers:
# ----> 3     val_pred = model.predict(x_val)
#       4     f1 = f1_score(y_val, val_pred, average='weighted')
#       5     f1s.append(f1)
#
# NameError: name 'x_val' is not defined

# %%
i_max = f1s.index(max(f1s))
best_c_model = classifiers[i_max]
best_c_model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_80/698895544.py in <module>
# ----> 1 i_max = f1s.index(max(f1s))
#       2 best_c_model = classifiers[i_max]
#       3 best_c_model
#
# ValueError: max() arg is an empty sequence

# %%
test = pd.read_csv("datasets/iris_test.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_80/3699623256.py in <module>
# ----> 1 test = pd.read_csv("datasets/iris_test.csv")
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/iris_test.csv'

# %%
test['species'] = ''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/4194270127.py in <module>
# ----> 1 test['species'] = ''
#
# NameError: name 'test' is not defined

# %%
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2541137542.py in <module>
# ----> 1 test.head()
#
# NameError: name 'test' is not defined

# %%
sc_test = pd.DataFrame(ct.transform(test))
sc_test.columns = column_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/872348868.py in <module>
# ----> 1 sc_test = pd.DataFrame(ct.transform(test))
#       2 sc_test.columns = column_names
#
# NameError: name 'test' is not defined

# %%
x_test = sc_test[num_columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2645706099.py in <module>
# ----> 1 x_test = sc_test[num_columns]
#
# NameError: name 'sc_test' is not defined

# %%
test['species'] = best_c_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/3558581894.py in <module>
# ----> 1 test['species'] = best_c_model.predict(x_test)
#
# NameError: name 'best_c_model' is not defined

# %%
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2541137542.py in <module>
# ----> 1 test.head()
#
# NameError: name 'test' is not defined

# %%
test_pred = best_c_model.predict(x_test)
f1 = f1_score(y_val, val_pred, average='weighted')
print(f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/2342797798.py in <module>
# ----> 1 test_pred = best_c_model.predict(x_test)
#       2 f1 = f1_score(y_val, val_pred, average='weighted')
#       3 print(f1)
#
# NameError: name 'best_c_model' is not defined

# %%
test.to_csv('task4_results/Fakhrutdinov_task14.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/1387939719.py in <module>
# ----> 1 test.to_csv('task4_results/Fakhrutdinov_task14.csv', index=False)
#
# NameError: name 'test' is not defined
